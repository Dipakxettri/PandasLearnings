# %%
import pandas as pd

# %%
# Series : are the labled array
series = pd.Series([1,2,3,4,5,6], index = ["a","b","c","d","e","f"])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %%
# DataFrame : 
df = pd.DataFrame({"names": ["Deepak","Rohan"], "marks" : [100,90]})
df
df.head()
df.tail()
# Out:
#     names  marks
# 0  Deepak    100
# 1   Rohan     90

# %%
data = pd.read_csv('./data/leads-100.csv')
data["Account Id"] # select specific columns 
data.loc[0:1] # select specifics rows
data.loc[0:1, ["Email 1", "Email 2"]] # select specifics rows and columns
# data.loc[2, ["Account Id"]]
# data.loc[0, ["Account Id"]] = 10 # updating specific data
data
# Out:
#     Index       Account Id         Lead Owner First Name  Last Name  \
# 0       1               10      Bethany Dixon     Victor    Cochran
# 1       2  e9AABddbCA4AFee    Andres Callahan    Maureen    Fuentes
# 2       3  99CF54fE56dDc5e       Angel Ortega      Ralph    Murillo
# 3       4  5B8C661A897ACE3      Dana Mcdonald    Richard     Obrien
# 4       5  2C7aEb5e8F432Ab        Sharon Cruz      Terri      Perry
# ..    ...              ...                ...        ...        ...
# 95     96  879AA6f76aCcEeF         Mary Terry      Erica   Garrison
# 96     97  f8EBCd52d798D8f     Vincent Mcneil   Fernando  Dickerson
# 97     98  bcCE5c7bEbdFfB2         Colin Choi     Sheila       Dyer
# 98     99  6cC0Dc8e4410B7E          Tony Beck     Cassie     Conrad
# 99    100  DCabaF160FbDda8  Dillon Stephenson  Charlotte   Browning
#
#                     Company                Phone 1               Phone 2  \
# 0   Grimes, Madden and Huff        +1-532-344-1362            2754733370
# ...

# %%
data.at[0,"Account Id"] # Accesing single element
# Out:
# 10

# %%
# Ascending 
data.sort_values("Phone 1", ascending= False)
# Out:
#     Index       Account Id         Lead Owner First Name   Last Name  \
# 2       3  99CF54fE56dDc5e       Angel Ortega      Ralph     Murillo
# 6       7  17aE538dCFAb3A6   Fernando Goodwin        Jim     Mullins
# 60     61  2cfD40e99Ea4FA2         Craig Ruiz       Brad      Zavala
# 97     98  bcCE5c7bEbdFfB2         Colin Choi     Sheila        Dyer
# 78     79  7aA9E8D5d3bBa0C     Cassidy Chavez     Shelby       Marsh
# ..    ...              ...                ...        ...         ...
# 80     81  decDeBEdBafdAc4  Craig Blankenship        Sue       Allen
# 28     29  21C8BAC4e24ad91       Mary Gilmore      Kerry       Lucas
# 99    100  DCabaF160FbDda8  Dillon Stephenson  Charlotte    Browning
# 47     48  ffF4fdAaAdA65bc       Scott Willis    Diamond     Stevens
# 64     65  83162d0B8c6fA0b        Colton Lowe    Stephen  Villarreal
#
#                           Company             Phone 1                 Phone 2  \
# ...
