# %%
import pandas as pd
coffie = pd.read_csv('./warmup-data/coffee.csv')

coffie.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
results = pd.read_parquet('./data/results.parquet')
results.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 results = pd.read_parquet('./data/results.parquet')
#       2 results.head()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/pandas/io/parquet.py:653, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     500 @doc(storage_options=_shared_docs["storage_options"])
#     501 def read_parquet(
#     502     path: FilePath | ReadBuffer[bytes],
#    (...)    510     **kwargs,
#     511 ) -> DataFrame:
#     512     """
#     513     Load a parquet object from the file path, returning a DataFrame.
#     514
#    (...)    650     1    4    9
#     651     """
# --> 653     impl = get_engine(engine)
#     655     if use_nullable_dtypes is not lib.no_default:
#     656         msg = (
# ...
